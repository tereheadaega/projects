# %% [markdown]
# # Metallurgical plant LLC "So we temper steel". Optimization of production processes

# %% [markdown]
# <h1>Content<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Построение-плана-и-исследовательский-анализ-данных" data-toc-modified-id="Построение-плана-и-исследовательский-анализ-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Построение плана и исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#План-исследования" data-toc-modified-id="План-исследования-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>План исследования</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Описание-этапа-обработки" data-toc-modified-id="Описание-этапа-обработки-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Описание этапа обработки</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Первичный-анализ-данных" data-toc-modified-id="Первичный-анализ-данных-1.2.4"><span class="toc-item-num">1.2.4&nbsp;&nbsp;</span>Первичный анализ данных</a></span></li><li><span><a href="#Вопросы" data-toc-modified-id="Вопросы-1.2.5"><span class="toc-item-num">1.2.5&nbsp;&nbsp;</span>Вопросы</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Предобработка-таблиц" data-toc-modified-id="Предобработка-таблиц-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Предобработка таблиц</a></span><ul class="toc-item"><li><span><a href="#data_arc" data-toc-modified-id="data_arc-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>data_arc</a></span></li><li><span><a href="#data_bulk" data-toc-modified-id="data_bulk-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>data_bulk</a></span></li><li><span><a href="#data_gas" data-toc-modified-id="data_gas-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>data_gas</a></span></li><li><span><a href="#data_wire" data-toc-modified-id="data_wire-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>data_wire</a></span></li><li><span><a href="#data_temp" data-toc-modified-id="data_temp-2.1.5"><span class="toc-item-num">2.1.5&nbsp;&nbsp;</span>data_temp</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.1.6"><span class="toc-item-num">2.1.6&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Разбиение-на-тренировочную-и-тестовую-выборку" data-toc-modified-id="Разбиение-на-тренировочную-и-тестовую-выборку-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Разбиение на тренировочную и тестовую выборку</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Построение-предсказательных-моделей" data-toc-modified-id="Построение-предсказательных-моделей-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Построение предсказательных моделей</a></span><ul class="toc-item"><li><span><a href="#LinearRegression" data-toc-modified-id="LinearRegression-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>LinearRegression</a></span></li><li><span><a href="#DecisionTreeRegressor" data-toc-modified-id="DecisionTreeRegressor-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>DecisionTreeRegressor</a></span></li><li><span><a href="#RandomForestRegressor" data-toc-modified-id="RandomForestRegressor-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>RandomForestRegressor</a></span></li><li><span><a href="#LGBMRegressor" data-toc-modified-id="LGBMRegressor-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>LGBMRegressor</a></span></li><li><span><a href="#CatBoostRegressor" data-toc-modified-id="CatBoostRegressor-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>CatBoostRegressor</a></span></li><li><span><a href="#Подбор-гиперпараметров-для-лучшей-модели" data-toc-modified-id="Подбор-гиперпараметров-для-лучшей-модели-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Подбор гиперпараметров для лучшей модели</a></span></li><li><span><a href="#Проверка-на-тестовом-наборе-данных" data-toc-modified-id="Проверка-на-тестовом-наборе-данных-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Проверка на тестовом наборе данных</a></span></li><li><span><a href="#Проверка-на-адекватность" data-toc-modified-id="Проверка-на-адекватность-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Проверка на адекватность</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></div>

# %% [markdown]
# ## Plan building and exploratory data analysis

# %% [markdown]
# **Purpose:** to optimize the production costs of the metallurgical plant OOO "Tak Temper Steel" by building a model that predicts the temperature of the steel.

# %% [markdown]
# ### Study plan

# %% [markdown]
# - Conducting exploratory data analysis
#     - familiarization with the technological process,
#     - inspection, study and analysis of data received from the customer,
#     - formulation of questions.
# - Preprocessing and machine learning
#     - work with anomalies,
#     - creation of new signs,
#     - splitting into test and training samples,
#     - creation of predictive models,
#     - selection of the best model,
#     - checking the best model on a test sample.
# - Report
#     - analysis of the obtained results,
#     - comparing the progress of work with a previously prepared plan,
#     - description of the resulting model and the parameters used in it,
#     - answers to research questions,
#     - the final conclusion.

# %% [markdown]
# ### Exploratory data analysis

# %% [markdown]
# #### Processing step description
#
# Steel is processed in a metal ladle with a capacity of about 100 tons. In order for the ladle to withstand high temperatures, it is lined with refractory bricks from the inside. Molten steel is poured into a ladle and heated to the desired temperature with graphite electrodes. They are installed in the lid of the bucket.
#
# Sulfur is removed from the alloy (desulfurization), the chemical composition is corrected by adding impurities, and samples are taken. Steel is alloyed - its composition is changed - by feeding pieces of alloy from a bunker for bulk materials or wire through a special tribe apparatus (English tribe, "mass").
#
# Before introducing alloying additives for the first time, the temperature of the steel is measured and its chemical analysis is carried out. Then the temperature is raised for several minutes, alloying materials are added and the alloy is purged with an inert gas. Then it is stirred and measured again. This cycle is repeated until the target chemical composition and optimum melting temperature are reached.
#
# Then the molten steel is sent to finish the metal or enters the continuous casting machine. From there, the finished product comes out in the form of slab blanks (English *slab*, “slab”).
#
# #### Description of data
#
# The data consists of seven files obtained from different sources:
# - `data_arc.csv` — electrode data;
# - `data_bulk.csv` - data on the supply of bulk materials (volume);
# - `data_bulk_time.csv` - data on the supply of bulk materials (time);
# - `data_gas.csv` — data on alloy gas purge;
# - `data_temp.csv` - temperature measurement results;
# - `data_wire.csv` - data on wire materials (volume);
# - `data_wire_time.csv` - data on wire materials (time).
#
# Next, we import the necessary libraries and load the data for further analysis.

# %% [markdown]
# #### Loading data

# %%
import seaborn as sb
import numpy as np
import os
import optuna
import pandas as pd
import time
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from lightgbm import LGBMRegressor
import catboost as cb
from catboost import CatBoostRegressor
from sklearn.dummy import DummyRegressor

from sklearn.metrics import mean_absolute_error, make_scorer

from sklearn.model_selection import cross_val_score, train_test_split, GridSearchCV, RandomizedSearchCV, RepeatedKFold, KFold
from sklearn.preprocessing import StandardScaler

# %%
# Set the constants to use
RND = 80822

# %%
# Load data
pth1 = 'data_arc.csv'
pth2 = '/datasets/final_steel/data_arc.csv'

pth3 = 'data_bulk.csv'
pth4 = '/datasets/final_steel/data_bulk.csv'

pth5 = 'data_bulk_time.csv'
pth6 = '/datasets/final_steel/data_bulk_time.csv'

pth7 = 'data_gas.csv'
pth8 = '/datasets/final_steel/data_gas.csv'

pth9 = 'data_temp.csv'
pth10 = '/datasets/final_steel/data_temp.csv'

pth11 = 'data_wire.csv'
pth12 = '/datasets/final_steel/data_wire.csv'

pth13 = 'data_wire_time.csv'
pth14 = '/datasets/final_steel/data_wire_time.csv'

if os.path.exists(pth1):
    data_arc = pd.read_csv(pth1)
    data_bulk = pd.read_csv(pth3)
    data_bulk_time = pd.read_csv(pth5)
    data_gas = pd.read_csv(pth7)
    data_temp = pd.read_csv(pth9)
    data_wire = pd.read_csv(pth11)
    data_wire_time = pd.read_csv(pth13)
elif os.path.exists(pth2):
    data_arc = pd.read_csv(pth2)
    data_bulk = pd.read_csv(pth4)
    data_bulk_time = pd.read_csv(pth6)
    data_gas = pd.read_csv(pth8)
    data_temp = pd.read_csv(pth10)
    data_wire = pd.read_csv(pth12)
    data_wire_time = pd.read_csv(pth14)
else:
    print('Error')

# %%
data = [data_arc,
data_bulk,
data_bulk_time,
data_gas,
data_temp,
data_wire,
data_wire_time]

discriptions = ['data_arc.csv — electrode data',
'data_bulk.csv — bulk material feed data (volume)',
'data_bulk_time.csv — bulk material feed data (time)',
'data_gas.csv — alloy gas purge data',
'data_temp.csv — temperature measurement results',
'data_wire.csv — wire materials data (volume)',
'data_wire_time.csv — wire material data (time)']

# %%
def analysis(df,discription):
    '''
        Input: df - table pd.DataFrame
               discription - the name of the table with a description of its contents
        Output: None
        Description: Function of initial acquaintance with data
    '''
    print('\n','\n','\n','\n','\n')
    print(discription)
    print()
    print('First three lines')
    display(df.head(3))
    print('Dataset size')
    display(df.shape)
    print('Three random lines')
    display(df.sample(3))
    print('Общая информация')
    display(df.info())
    print('Count gaps in data')
    print(df.isna().sum())
    print('Counting the number of duplicates in data')
    print(df.duplicated().sum())
    print('Statistics')
    display(df.describe(include='all'))
    for row in df.columns:
        print('Unique Column Values:', row)
        print(df[row].unique())
    print()
    print('The initial is over.')

# %% [markdown]
# #### Первичный анализ данных

# %%
for i in range(len(data)):
    analysis(data[i], discriptions[i])
# Out:
#
#
#
#
#
# data_arc.csv — electrode data
#
# First three lines
#    key Начало нагрева дугой  Конец нагрева дугой  Активная мощность  \
# 0    1  2019-05-03 11:02:14  2019-05-03 11:06:02           0.976059
# 1    1  2019-05-03 11:07:28  2019-05-03 11:10:33           0.805607
# 2    1  2019-05-03 11:11:44  2019-05-03 11:14:36           0.744363
#
#    Реактивная мощность
# 0             0.687084
# 1             0.520285
# 2             0.498805
# Dataset size
# (14876, 5)
# Three random lines
#        key Начало нагрева дугой  Конец нагрева дугой  Активная мощность  \
# 6080  1325  2019-06-19 23:47:08  2019-06-19 23:49:53           0.755424
# 8492  1845  2019-07-07 23:07:31  2019-07-07 23:10:01           0.681821
# 6059  1320  2019-06-19 20:09:34  2019-06-19 20:12:28           0.580617
#
#       Реактивная мощность
# 6080             0.510341
# 8492             0.464722
# 6059             0.531824
# Общая информация
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14876 entries, 0 to 14875
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   key                   14876 non-null  int64
#  1   Начало нагрева дугой  14876 non-null  object
#  2   Конец нагрева дугой   14876 non-null  object
#  3   Активная мощность     14876 non-null  float64
#  4   Реактивная мощность   14876 non-null  float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 581.2+ KB
# None
# Count gaps in data
# key                     0
# Начало нагрева дугой    0
# Конец нагрева дугой     0
# Активная мощность       0
# Реактивная мощность     0
# dtype: int64
# Counting the number of duplicates in data
# 0
# Statistics
#                  key Начало нагрева дугой  Конец нагрева дугой  \
# count   14876.000000                14876                14876
# unique           NaN                14875                14876
# top              NaN  2019-06-10 22:02:03  2019-05-03 11:06:02
# freq             NaN                    2                    1
# mean     1615.220422                  NaN                  NaN
# std       934.571502                  NaN                  NaN
# min         1.000000                  NaN                  NaN
# 25%       806.000000                  NaN                  NaN
# 50%      1617.000000                  NaN                  NaN
# 75%      2429.000000                  NaN                  NaN
# max      3241.000000                  NaN                  NaN
#
#         Активная мощность  Реактивная мощность
# count        14876.000000         14876.000000
# unique                NaN                  NaN
# top                   NaN                  NaN
# freq                  NaN                  NaN
# mean             0.670441             0.452592
# std              0.408159             5.878702
# min              0.030002          -715.504924
# 25%              0.395297             0.290991
# 50%              0.555517             0.415962
# 75%              0.857034             0.637371
# max              3.731596             2.676388
# Unique Column Values: key
# [   1    2    3 ... 3239 3240 3241]
# Unique Column Values: Начало нагрева дугой
# ['2019-05-03 11:02:14' '2019-05-03 11:07:28' '2019-05-03 11:11:44' ...
#  '2019-09-01 04:16:41' '2019-09-01 04:31:51' '2019-09-01 04:34:47']
# Unique Column Values: Конец нагрева дугой
# ['2019-05-03 11:06:02' '2019-05-03 11:10:33' '2019-05-03 11:14:36' ...
#  '2019-09-01 04:19:45' '2019-09-01 04:32:48' '2019-09-01 04:36:08']
# Unique Column Values: Активная мощность
# [0.97605875 0.80560708 0.74436343 ... 0.73389947 0.22069395 0.30658007]
# Unique Column Values: Реактивная мощность
# [0.68708372 0.52028525 0.4988054  ... 0.47565365 0.1457684  0.19670773]
#
# The initial is over.
#
#
#
#
#
#
# data_bulk.csv — bulk material feed data (volume)
#
# First three lines
#    key  Bulk 1  Bulk 2  Bulk 3  Bulk 4  Bulk 5  Bulk 6  Bulk 7  Bulk 8  \
# 0    1     NaN     NaN     NaN    43.0     NaN     NaN     NaN     NaN
# 1    2     NaN     NaN     NaN    73.0     NaN     NaN     NaN     NaN
# 2    3     NaN     NaN     NaN    34.0     NaN     NaN     NaN     NaN
#
#    Bulk 9  Bulk 10  Bulk 11  Bulk 12  Bulk 13  Bulk 14  Bulk 15
# 0     NaN      NaN      NaN    206.0      NaN    150.0    154.0
# 1     NaN      NaN      NaN    206.0      NaN    149.0    154.0
# 2     NaN      NaN      NaN    205.0      NaN    152.0    153.0
# Dataset size
# (3129, 16)
# Three random lines
#        key  Bulk 1  Bulk 2  Bulk 3  Bulk 4  Bulk 5  Bulk 6  Bulk 7  Bulk 8  \
# 2120  2192     NaN     NaN     NaN   154.0     NaN     NaN     NaN     NaN
# 969   1014     NaN     NaN     NaN     NaN     NaN    88.0     NaN     NaN
# 199    215     NaN     NaN     NaN   123.0     NaN     NaN     NaN     NaN
#
#       Bulk 9  Bulk 10  Bulk 11  Bulk 12  Bulk 13  Bulk 14  Bulk 15
# 2120     NaN      NaN      NaN    330.0      NaN    136.0    228.0
# 969      NaN      NaN      NaN    206.0      NaN    211.0    102.0
# 199      NaN      NaN      NaN    206.0      NaN    126.0    206.0
# Общая информация
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3129 entries, 0 to 3128
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   key      3129 non-null   int64
#  1   Bulk 1   252 non-null
#  3.43200000e-02 5.51865650e+01 5.52208820e+01 7.23122480e+01
#  5.01072010e+01 3.52123220e+01 3.51780010e+01 4.51994440e+01
#  3.02016030e+01 3.01672820e+01]
# Unique Column Values: Wire 7
# [      nan  5.035472  8.49004   1.053936  0.234208 11.417641 32.847674
#  12.354473  9.134113  8.490041  9.017009]
# Unique Column Values: Wire 8
# [       nan  46.002319  46.094879  46.187439  46.279999  45.354401
#   45.076721  68.494405 102.762401  95.244248  48.001203  53.652562
#   48.089603  48.001202]
# Unique Column Values: Wire 9
# [      nan 35.0532    4.6228   35.0168   10.01     53.071201 55.000397
#  23.5508   90.053604 30.066399 28.0644   62.0256   17.0352   10.0464
#  15.0696   22.058401 30.1028   30.030001 43.862003 48.193606 25.1888
#  42.0784   63.0448   11.3568   39.967201  7.753203]
#
# The initial is over.
#
#
#
#
#
#
# data_wire_time.csv — wire material data (time)
#
# First three lines
#    key               Wire 1 Wire 2 Wire 3 Wire 4 Wire 5 Wire 6 Wire 7 Wire 8  \
# 0    1  2019-05-03 11:11:41    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1    2  2019-05-03 11:46:10    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2    3  2019-05-03 12:13:47    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#   Wire 9
# 0    NaN
# 1    NaN
# 2    NaN
# Dataset size
# (3081, 10)
# Three random lines
#        key               Wire 1 Wire 2 Wire 3 Wire 4 Wire 5 Wire 6 Wire 7  \
# 2209  2320  2019-07-30 16:29:54    NaN    NaN    NaN    NaN    NaN    NaN
# 1548  1627  2019-06-30 16:44:42    NaN    NaN    NaN    NaN    NaN    NaN
# 850    904  2019-06-05 16:18:46    NaN    NaN    NaN    NaN    NaN    NaN
#
#      Wire 8 Wire 9
# 2209    NaN    NaN
# 1548    NaN    NaN
# 850     NaN    NaN
# Общая информация
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3081 entries, 0 to 3080
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3081 non-null   int64
#  1   Wire 1  3055 non-null   object
#  2   Wire 2  1079 non-null   object
#  3   Wire 3  63 non-null     object
#  4   Wire 4  14 non-null     object
#  5   Wire 5  1 non-null      object
#  6   Wire 6  73 non-null     object
#  7   Wire 7  11 non-null     object
#  8   Wire 8  19 non-null     object
#  9   Wire 9  29 non-null     object
# dtypes: int64(1), object(9)
# memory usage: 240.8+ KB
# None
# Count gaps in data
# key          0
# Wire 1      26
# Wire 2    2002
# Wire 3    3018
# Wire 4    3067
# Wire 5    3080
# Wire 6    3008
# Wire 7    3070
# Wire 8    3062
# Wire 9    3052
# dtype: int64
# Counting the number of duplicates in data
# 0
# Statistics
#                 key               Wire 1               Wire 2  \
# count   3081.000000                 3055                 1079
# unique          NaN                 3055                 1079
# top             NaN  2019-05-03 11:11:41  2019-05-03 13:32:06
# freq            NaN                    1                    1
# mean    1623.426485                  NaN                  NaN
# std      932.996726                  NaN                  NaN
# min        1.000000                  NaN                  NaN
# 25%      823.000000                  NaN                  NaN
# 50%     1619.000000                  NaN                  NaN
# 75%     2434.000000                  NaN                  NaN
# max     3241.000000                  NaN                  NaN
#
#                      Wire 3               Wire 4               Wire 5  \
# count                    63                   14                    1
# unique                   63                   14                    1
# top     2019-05-04 04:47:53  2019-05-07 08:48:23  2019-08-08 16:01:07
# freq                      1                    1                    1
# mean                    NaN                  NaN                  NaN
# std                     NaN                  NaN                  NaN
# min                     NaN                  NaN                  NaN
# 25%                     NaN                  NaN                  NaN
# 50%                     NaN                  NaN                  NaN
# 75%                     NaN                  NaN                  NaN
# max                     NaN                  NaN                  NaN
#
#
#  '2019-05-14 05:14:25' '2019-07-05 17:34:22' '2019-07-18 17:36:23'
#  '2019-07-18 18:58:07' '2019-08-11 11:12:56' '2019-08-11 12:13:47'
#  '2019-08-11 13:20:31' '2019-08-11 13:54:30' '2019-08-11 14:33:40'
#  '2019-08-11 15:09:29']
# Unique Column Values: Wire 9
# [nan '2019-05-04 16:09:11' '2019-06-01 02:25:26' '2019-06-01 04:57:26'
#  '2019-06-01 05:45:01' '2019-06-01 07:26:42' '2019-06-01 09:54:01'
#  '2019-06-07 14:29:39' '2019-06-07 20:28:19' '2019-06-07 21:03:47'
#  '2019-06-07 21:42:24' '2019-06-07 22:47:35' '2019-06-07 23:25:28'
#  '2019-06-07 23:59:16' '2019-06-09 08:20:14' '2019-06-09 10:26:00'
#  '2019-07-02 05:22:29' '2019-07-02 06:41:51' '2019-07-02 08:17:45'
#  '2019-07-02 12:29:04' '2019-07-02 13:04:13' '2019-08-04 19:49:15'
#  '2019-08-04 20:48:59' '2019-08-04 22:04:50' '2019-08-04 23:15:18'
#  '2019-08-05 00:21:11' '2019-08-05 01:13:57' '2019-08-05 02:48:39'
#  '2019-08-05 04:16:10' '2019-08-29 03:51:31']
#
# The initial is over.

# %% [markdown]
# **Conclusion**
#
# data_arc - data about the electrodes
#
# Contains 5 columns:
# key, Arc heating start, Arc heating end, Active power, Reactive power
# and 14876 lines without gaps and duplicates.
# The columns 'Arc heating start' and 'Arc heating end' are of type object.
# Obviously, the "Reactive power" and "Real power" columns have outliers, which can be seen in the graphs below. Keys where outliers are present will be removed from the study.

# %%
data_arc.boxplot(column='Реактивная мощность')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/0p/_prrccxj0n139bry1p6r136h0000gn/T/ipykernel_21645/2982536311.py in <module>
# ----> 1 data_arc.boxplot(column='Reactive power')
#       2 plt.show()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/plotting/_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     509 ):
#     510     plot_backend = _get_plot_backend(backend)
# --> 511     return plot_backend.boxplot_frame(
#     512         self,
#     513         column=column,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/boxplot.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     392     import matplotlib.pyplot as plt
#     393
# --> 394     ax = boxplot(
#     395         self,
#     396         column=column,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/boxplot.py in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     369             columns = data.columns
#     370         else:
# --> 371             data = data[columns]
#     372
#     373         result = plot_group(columns, data.values.T, ax)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1372                 if use_interval_msg:
#    1373                     key = list(key)
# -> 1374                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['Reactive power'], dtype='object')] are in the [columns]"

# %%
data_arc.boxplot(column='Active power')
plt.show()

# %% [markdown]
# data_bulk - data on the supply of bulk materials (volume)
#
# Contains 16 columns. The first is the key, and all subsequent ones are the designations of bulk materials and 3129 lines.
# Each column of bulk materials has gaps, but there are no duplicate rows.
# At the same time, the distribution of values in most columns of bulk materials does not correspond to the normal one, which can be seen in the diagrams below.

# %%
for row in data_bulk.columns:
    data_bulk[row].hist(bins=50,legend= True)
    plt.show()

# %% [markdown]
# data_bulk_time - data on the supply of bulk materials (time)
# Contains information about the time of adding bulk materials. Conclusions about the number of gaps and duplicates are the same as those for the data_bulk table

# %% [markdown]
# data_gas - gas purge data
#
# Contains two columns: "key" and "Gas 1" and 3239 rows without gaps or duplicates.
# The values in the "Gas 1" column are normally distributed, however, there are outliers, which can be clearly seen in the second graph.

# %%
data_gas['Газ 1'].hist(bins=50)
plt.show()

# %%
data_gas.boxplot(column='Газ 1')
plt.show()

# %% [markdown]
# data_temp - temperature measurement results
#
# Contains three columns: "key", "Sampling time" of object type, "Temperature" and 15907 rows.
# The values in the "Temperature" column are normally distributed, however, there are outliers, which can be seen in the second graph. Note that there are 2901 gaps in this column, but there are no repetitions. At the same time, there are measurements in which the measurement temperature is lower than the melting temperature of the metal. Keys in which the first or last temperature reading is below 1500 degrees will be removed from the study. Also, keys for which only one temperature measurement is specified will be removed from the study.

# %%
data_temp['Температура'].hist(bins=50)
plt.show()

# %%
data_temp.boxplot(column='Температура')
plt.show()

# %% [markdown]
# data_wire - wire materials data (volume)
#
# Contains ten columns: keys, nine wire materials and 3081 rows.
# All columns except the first one have gaps, but there are no duplicates.
# At the same time, the distribution of values in most columns of wire materials does not correspond to the normal one, which can be seen in the diagrams below.

# %%
for row in data_wire.columns:
    data_wire[row].hist(bins=50,legend= True)
    plt.show()

# %% [markdown]
# data_wire_time - data about wire materials (time)
#
# Contains information about the time of application of wire materials. Findings about the number of gaps and duplicates match those for the data_wire table.

# %% [markdown]
# ### Conclusion
#
#
# In this section, a plan for further work was prepared. The research steps were described with a description of the necessary actions, and the necessary libraries and dataframes were loaded.
#
# A first analysis of the data was carried out. The first lines of each dataframe, their sizes and main characteristics were displayed. Further, conclusions were presented on the data obtained and refinement graphs, allowing to determine the type of distribution within the data and the presence of outliers.
#
# It is important to note that not all keys occur in all tables, and at the next stage of the study it is necessary to leave only those keys that occur in each table.

# %% [markdown]
# ## Data preprocessing
#
# At this stage, in order to be able to achieve the goal, it is necessary to combine various tables into one dataframe, with which predictive models will work. Let's call it df and do the preparatory work to add table data to it.
#
#
#
# ### Table preprocessing
# #### data_arc
#
# Let's convert the values ​​of the columns Start of heating with an arc and End of heating with an arc to the temporary data type.
# Then we remove the keys where active and reactive power are emissions.
# After that, we will create a new column that will store the heating time, and then delete the columns with the start and end times of the heating.
# At the end, we will group by key, finding the total heating time and the average values ​​of active and reactive power.

# %%
data_arc.shape

# %%
data_arc['Начало нагрева дугой'] = data_arc['Начало нагрева дугой'].astype('datetime64')
data_arc['Конец нагрева дугой'] = data_arc['Конец нагрева дугой'].astype('datetime64')

# %%
data_arc.loc[data_arc['Реактивная мощность']<0]

# %%
# remove the key from the study, where the reactive power is less than zero.
data_arc = data_arc.loc[data_arc['key']!=2116]

# %%
data_arc.shape

# %%
data_arc.loc[data_arc['Активная мощность']> 3.5]

# %%
# remove from the study the measurement, where the active power is greater than 3.5
data_arc = data_arc.loc[data_arc['key']!=1689]

# %%
data_arc.shape

# %%
# Let's create a column where the arc heating time will be stored
data_arc['Время нагрева дугой'] = (data_arc['Конец нагрева дугой'] - data_arc['Начало нагрева дугой']).dt.total_seconds()

# %%
data_arc.head(5)

# %%
# delete two columns: 'Начало нагрева дугой','Конец нагрева дугой'.
data_arc = data_arc.drop(['Начало нагрева дугой','Конец нагрева дугой'],axis=1)

# %%
data_arc.head(3)

# %%
data_arc_sum_time = data_arc[['key','Время нагрева дугой']].groupby(by=['key'], as_index = False).sum()

# %%
data_arc_sum_time.rename(columns={'Время нагрева дугой': 'Суммарное время нагрева'}, inplace=True)
data_arc_sum_time.head(3)

# %%
# Let's create a column where the number of arc heatings will be stored
data_arc_count_heats = data_arc.groupby(['key']).size().reset_index(name='Количество нагревов')

# %%
data_arc_count_heats.head(3)

# %%
data_arc_power = data_arc[['key','Активная мощность', 'Реактивная мощность']].groupby(by=['key'], as_index = False).mean()

# %%
data_arc_power.insert(3,'Отношение мощностей', data_arc_power['Реактивная мощность']/data_arc_power['Активная мощность'])

# %%
data_arc_power.head(3)

# %%
data_arc_new = data_arc_power.join(data_arc_sum_time.set_index('key'), on='key')

# %%
data_arc_new = data_arc_new.join(data_arc_count_heats.set_index('key'), on='key')

# %%
# This table stores the average values of active and reactive power, 
# as well as the total heating time for each key
display(data_arc_new.head(3))
data_arc_new.shape

# %% [markdown]
# #### data_bulk
#
# the data_bulk table contains information about the supplied bulk materials. Among the data there is one bulk material that was used only once. For more correct work of the model, this material will be removed from the study.

# %%
data_bulk.shape

# %%
# Add a sign - the amount of bulk materials supplied
data_bulk['Bulk count']=data_bulk.apply(lambda x: 15 - x.isnull().sum(), axis='columns')

# %%
data_bulk = data_bulk.drop('Bulk 8', axis=1)

# %%
display(data_bulk.head(3))
data_bulk.shape

# %%
display(data_bulk.head(3))
data_bulk.shape

# %%
bulk_time_list = data_bulk_time.columns
bulk_time_list = bulk_time_list.drop('key')
data_bulk_time[bulk_time_list] = data_bulk_time[bulk_time_list].applymap(lambda x : pd.to_datetime(x,format='%Y%m%d %H:%M:%S'))

# %%
# Add the time of the first and last bulk additives to the table
data_bulk_time['Первая сыпучая добавка'] = data_bulk_time[bulk_time_list].min(axis=1)
data_bulk_time['Последняя сыпучая добавка'] = data_bulk_time[bulk_time_list].max(axis=1)

# %%
data_bulk_time = data_bulk_time.drop(bulk_time_list,axis=1)

# %%
print(data_bulk_time.shape)
data_bulk_time.head(3)

# %%
data_bulk_time['Время сыпучих добавок'] = (data_bulk_time['Последняя сыпучая добавка'] - data_bulk_time['Первая сыпучая добавка']).dt.total_seconds()

# %%
data_bulk_time = data_bulk_time.drop(['Первая сыпучая добавка', 'Последняя сыпучая добавка'],axis=1)

# %%
data_bulk_time.head(3)

# %%
df = data_arc_new.join(data_bulk.set_index('key'), on='key', how='inner')

# %%
df = df.join(data_bulk_time.set_index('key'), on='key', how='inner')

# %%
display(df.head(3))
df.shape

# %% [markdown]
# #### data_gas
#
# This table has two meanings that stand out from the rest. These measurements will be removed from further research.

# %%
data_gas.shape

# %%
data_gas.loc[data_gas['Газ 1']> 60]

# %%
data_gas.shape

# %%
display(data_gas.head(3))
data_gas.shape

# %%
df = df.join(data_gas.set_index('key'), on='key', how='inner')

# %%
display(df.head(3))
df.shape

# %% [markdown]
# ####  data_wire
#
# The data_wire table contains information about the wire materials fed. Among the data there is one material that was used only once. For more correct work of the model, this material will be removed from the study.

# %%
data_wire.shape

# %%
# Let's add a sign - the number of submitted wire materials
data_wire['Wire count']=data_wire.apply(lambda x: 9 - x.isnull().sum(), axis='columns')

# %%
data_wire = data_wire.drop('Wire 5', axis=1)

# %%
display(data_wire.head(3))
data_wire.shape

# %%
wire_time_list = data_wire_time.columns
wire_time_list = wire_time_list.drop('key')
data_wire_time[wire_time_list] = data_wire_time[wire_time_list].applymap(lambda x : pd.to_datetime(x,format='%Y%m%d %H:%M:%S'))

# %%
data_wire_time['Первая проволока'] = data_wire_time[wire_time_list].min(axis=1)
data_wire_time['Последняя проволока'] = data_wire_time[wire_time_list].max(axis=1)

# %%
data_wire_time = data_wire_time.drop(wire_time_list,axis=1)

# %%
print(data_wire_time.shape)
data_wire_time.head(3)

# %%
data_wire_time['Время проволоки'] = (data_wire_time['Последняя проволока'] - data_wire_time['Первая проволока']).dt.total_seconds()

# %%
data_wire_time = data_wire_time.drop(['Первая проволока', 'Последняя проволока'],axis=1)

# %%
df = df.join(data_wire.set_index('key'), on='key', how='inner')

# %%
df = df.join(data_wire_time.set_index('key'), on='key', how='inner')

# %%
display(df.head(3))
df.shape

# %% [markdown]
# #### data_temp
#
# The task of the study is to predict the last temperature measurement. Let's group the measurements in such a way as to save only the last temperature measurement, however, we will first get rid of outliers in the data.

# %%
data_temp.shape

# %%
data_temp = data_temp.loc[~data_temp['key'].isin([867, 1214, 1619, 1818, 2052, 2561])]

# %%
data_temp = data_temp.dropna()

# %%
display(data_temp.head(3))
data_temp.shape

# %%
data_temp_count = data_temp.groupby(['key']).size().reset_index(name='Количество замеров')

# %%
display(data_temp_count.tail(3))
data_temp_count.shape

# %% [markdown]
# It can be seen that there are keys with a single dimension. However, according to the workflow, there must be at least two measurements, so keys with a single measurement will be deleted.

# %%
data_temp_count = data_temp_count.loc[data_temp_count['Количество замеров']> 1]

# %%
display(data_temp_count.tail(3))
data_temp_count.shape

# %%
print('Number of measurements with a melting temperature below the melting temperature of the metal before grouping',data_temp.loc[data_temp['Температура']< 1500]['key'].count())

# %%
data_temp_first_temp = data_temp.groupby(by=['key'], as_index = False).nth(0)

# %%
data_temp_first_temp = data_temp_first_temp.drop(['Время замера'], axis=1)

# %%
data_temp_first_temp.rename(columns={'Температура': 'Первая температура'}, inplace=True)

# %%
data_temp_first_temp.head(3)

# %%
data_temp_group = data_temp.groupby(by=['key'], as_index = False).nth(-1)

# %%
data_temp_group = data_temp_group.drop('Время замера',axis=1)

# %%
print('Количетсво измерений с температурой плавления ниже температуры плавления металла после группировки', data_temp_group[data_temp_group['Температура']<1500]['key'].count())

# %% [markdown]
# Number of measurements with a melting temperature below the melting temperature of the metal after grouping

# %% [markdown]
# Based on the assumption that during metal processing the melting temperature may decrease or errors are possible, we will assume that there are no errors in the temperature regime and it is not necessary to delete these data.

# %%
display(data_temp_group.head(3))
data_temp_group.shape

# %%
df = df.join(data_temp_group.set_index('key'), on='key', how='inner')

# %%
df = df.join(data_temp_first_temp.set_index('key'), on='key', how='inner')

# %%
df = df.join(data_temp_count.set_index('key'), on='key', how='inner')

# %% [markdown]
# At the end of the preparation, we will remove the column with the keys.

# %%
df = df.drop('key', axis=1)

# %%
display(df.head(3))
df.shape

# %%
print('Heatmap корреляций признаков:')
plt.figure(figsize=(30, 30))
heatmap = sb.heatmap(df.corr(), vmin=-1, vmax=1, annot=True) 
plt.show()

# %% [markdown]
# From the resulting graph, we can conclude that there is no multicollinearity.
# We can also note a strong linear relationship between some features. Let's remove some features from the study, namely: Reactive power, Bulk 7, Bulk 9, Wire 9

# %%
df = df.drop(['Реактивная мощность', 'Bulk 7', 'Bulk 9', 'Wire 2','Wire 8','Wire 9'], axis=1)

# %% [markdown]
# #### Conclusion
#
# In this section, data preparation has been carried out. Keys containing false data have been removed. Also, new features were added, such as the power ratio, the total heating time of the boiler, the number of heatings, the duration of adding bulk additives and wire materials, as well as their number and the initial measurement of the temperature of the alloy with the number of measurements.
#
# After the analysis, it was found that some parameters have a very high degree of correlation and they were removed from further research.
#
# The final table, which will be divided into training and test samples, consists of 2321 rows and 35 features.

# %% [markdown]
# ### Split into training and test set

# %%
target = df['Температура']
features = df.drop('Температура', axis=1)

# %%
features_train, features_test, target_train, target_test = train_test_split(
    features, target, test_size=0.25, random_state= RND)

# %%
print('features_train shape',features_train.shape)
print('features_test shape',features_test.shape)
print('target_train shape',target_train.shape)
print('target_test shape',target_test.shape)

# %%
numeric = features_train.columns

# %%
features_train_scaled = features_train.copy(deep=True)
features_test_scaled = features_test.copy(deep=True)

# %%
scaler = StandardScaler()
scaler.fit(features_train_scaled)
features_train_scaled[numeric] = scaler.transform(features_train_scaled[numeric])
features_test_scaled[numeric] = scaler.transform(features_test[numeric])

# %%
features_train_scaled = features_train_scaled.fillna(0)

# %%
features_train_nona = features_train.fillna(0)

# %%
features_test_nona = features_test.fillna(0)

# %%
display(features_train_scaled.head(1))
display(features_train.head(1))

# %% [markdown]
# ### Conclusion
#
# In this section, the sample was divided into training and test. The target feature was isolated separately. Gaps were filled in the training and test sets and the data were standardized for use in linear regression.
#
# At the next stage, several models will be built and studied based on the samples prepared at this stage.

# %% [markdown]
# ## Building predictive models

# %% [markdown]
# In this step, linear regression, tree and forest models, as well as LGBMR and Catboost gradient boosting models will be considered.

# %% [markdown]
# ### LinearRegression

# %% [markdown]
# For a linear regression model, apply cross-validation

# %%
model_linear = LinearRegression()
scores = cross_val_score(model_linear, features_train_scaled, target_train, scoring = 'neg_mean_absolute_error', cv=5) 
print('Наилучшее значение метрики:', round(min(scores),1))
# Out:
# Наилучшее значение метрики: -7.0

# %% [markdown]
# ### DecisionTreeRegressor

# %%
# %%time

model_tree = DecisionTreeRegressor(random_state=RND)

scores = cross_val_score(model_tree, features_train_nona, target_train, scoring = 'neg_mean_absolute_error', cv=5) 
print('Наилучшее значение метрики:', round(min(scores),1))
# Out:
# Наилучшее значение метрики: -9.9
# CPU times: user 733 ms, sys: 292 ms, total: 1.03 s
# Wall time: 162 ms

# %% [markdown]
# ### RandomForestRegressor

# %%
# %%time

model_forest = RandomForestRegressor(random_state=RND)

param_forest = {'n_estimators': range (10, 1100, 200),
                'max_depth': range (3,13, 2),
                'min_samples_split': range (2,10,3)
            }
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=RND)
rnd_search_forest = RandomizedSearchCV(model_forest, param_forest, scoring= 'neg_mean_absolute_error', cv= cv, n_jobs=-1)
rnd_search_forest.fit(features_train_nona, target_train)

print('Лучшие параметры:', rnd_search_forest.best_params_)
print('Наилучшее значение метрики: %.1f'% rnd_search_forest.best_score_)
# Out:
# Лучшие параметры: {'n_estimators': 210, 'min_samples_split': 2, 'max_depth': 11}
# Наилучшее значение метрики: -6.2
# CPU times: user 3.89 s, sys: 419 ms, total: 4.31 s
# Wall time: 3min 11s

# %% [markdown]
# ### LGBMRegressor

# %%
# %%time

model_lgbmr = LGBMRegressor(random_state=RND)
cv = RepeatedKFold(n_splits=20, n_repeats=5, random_state=RND)
n_scores = cross_val_score(model_lgbmr, features_train, target_train, scoring= 'neg_mean_absolute_error', cv= cv, n_jobs=-1)

model_lgbmr.fit(features_train_nona, target_train)


print('Наилучшее значение метрики:', round(np.mean(n_scores),1))
# Out:
# Наилучшее значение метрики: -6.1
# CPU times: user 2.53 s, sys: 426 ms, total: 2.95 s
# Wall time: 6.75 s

# %% [markdown]
# ### CatBoostRegressor

# %%
# %%time

cat = CatBoostRegressor(verbose=False, loss_function='MAE')

parametrs_cat_rnd = {'learning_rate': np.arange(0.001, 0.04),
                      'l2_leaf_reg': np.arange(1.0, 4, 0.5),
                      'max_depth': range (3,12, 1)}
rnd_search_cat = RandomizedSearchCV(cat, parametrs_cat_rnd, scoring= 'neg_mean_absolute_error', cv=5, n_jobs=-1)
rnd_search_cat.fit(features_train, target_train)

print('MAE модели:', rnd_search_cat.best_score_)
# Out:
# MAE модели: -7.0325058273115335
# CPU times: user 41.6 s, sys: 3.74 s, total: 45.3 s
# Wall time: 3min 5s

# %%
# %%time

model_cat = CatBoostRegressor(verbose=False, loss_function='MAE')

parametrs_cat_rnd = {'learning_rate': np.arange(0.005, 0.03, 0.005),
                      'l2_leaf_reg': np.arange(1, 3, 0.5),
                      'max_depth': range (3,12, 2)}

cv = RepeatedKFold(n_splits=5, n_repeats=3, random_state=RND)
rnd_search_cat = RandomizedSearchCV(model_cat, parametrs_cat_rnd, scoring= 'neg_mean_absolute_error' ,cv= cv, n_jobs=-1)
rnd_search_cat.fit(features_train, target_train)

print('Лучшие параметры:', rnd_search_cat.best_params_)
print('Наилучшее значение метрики: %.1f'% rnd_search_cat.best_score_)
# Out:
# Лучшие параметры: {'max_depth': 3, 'learning_rate': 0.025, 'l2_leaf_reg': 2.0}
# Наилучшее значение метрики: -6.0
# CPU times: user 2.43 s, sys: 1 s, total: 3.44 s
# Wall time: 6min 9s

# %%
# %%time

model_cat = CatBoostRegressor(verbose=False, loss_function='MAE')

parametrs_cat_rnd = {'learning_rate': np.arange(0.005, 0.03, 0.01),
                      'l2_leaf_reg': np.arange(1, 3, 1),
                      'max_depth': range (3,12, 4)}

randomized_search_result = model_cat.randomized_search(parametrs_cat_rnd,
                                                   X=features_train,
                                                   y=target_train,
                                                   partition_random_seed=RND,
                                                    verbose=False)
# Out:
# bestTest = 6.003011204
# bestIteration = 999
#
#
# bestTest = 12.06538315
# bestIteration = 999
#
#
# bestTest = 12.06383608
# bestIteration = 999
#
#
# bestTest = 6.02991231
# bestIteration = 999
#
#
# bestTest = 5.960766321
# bestIteration = 992
#
#
# bestTest = 12.01525215
# bestIteration = 992
#
#
# bestTest = 18.68603731
# bestIteration = 999
#
#
# bestTest = 11.44396405
# bestIteration = 931
#
#
# bestTest = 40.75988889
# bestIteration = 999
#
#
# Iteration with suspicious time 341 sec ignored in overall statistics.
#
# bestTest = 29.8188437
# bestIteration = 993
#
# Training on fold [0/3]
#
# bestTest = 7.089136475
# bestIteration = 993
#
# Training on fold [1/3]
#
# bestTest = 6.221968868
# bestIteration = 991
#
# Training on fold [2/3]
#
# bestTest = 6.072999957
# bestIteration = 881
#
# CPU times: user 6min 37s, sys: 15.6 s, total: 6min 53s
# Wall time: 6min 22s

# %%
model_cat = CatBoostRegressor(verbose=False, loss_function='MAE')
model_cat.fit(features_train, target_train)

# %%
sorted_feature_importance = model_cat.feature_importances_.argsort()
plt.figure(figsize=(20, 15))
plt.barh(features.columns[sorted_feature_importance], 
        model_cat.feature_importances_[sorted_feature_importance], 
        color='turquoise')
plt.xlabel("CatBoost Feature Importance")
plt.show()

# %% [markdown]
# ### Selection of hyperparameters for the best model

# %% [markdown]
# The lowest value of the MAE metric was shown by the CatBoost model. After studying the importance of features, you can remove some. Next, an algorithm for finding the best hyperparameters will be used.

# %%
features_train = features_train.drop(['Bulk 2','Bulk 13', 'Wire 7','Wire 4'], axis=1)
features_test = features_test.drop(['Bulk 2','Bulk 13', 'Wire 7','Wire 4'], axis=1)

# %%
def objective_cat(trial, X, y):
    param = {
         "learning_rate": trial.suggest_float('learning_rate', 0.001, 0.04),
         "max_depth": trial.suggest_int('max_depth', 3, 12),
         "l2_leaf_reg": trial.suggest_discrete_uniform('l2_leaf_reg', 1.0, 4, 0.5),
         "min_child_samples": trial.suggest_categorical('min_child_samples', [1, 4, 8, 16, 32]),
        'loss_function': 'MAE'      
    }
    
    cv = KFold(n_splits=5, shuffle=True, random_state=RND)
    
    cv_predicts = np.empty(5)

    for idx, (train_idx, test_idx) in enumerate(cv.split(X, y)):
        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]
    
        model = CatBoostRegressor(verbose=False, **param, random_seed=RND)
    
        model.fit(X_train,
                  y_train,
                  eval_set=[(X_test, y_test)],
                  early_stopping_rounds=100,
                  use_best_model=True,
                  verbose=2)
        preds = model.predict(X_test)        
        cv_predicts[idx] = mean_absolute_error(y_test, preds)   
    
    
    
    return np.mean(cv_predicts)

# %%
study_cat = optuna.create_study(direction="minimize", study_name="CatBoostRegressor")
func_cat = lambda trial: objective_cat(trial, features_train, target_train)

study_cat.optimize(func_cat, n_trials=10, show_progress_bar=True)
# Out:
# [I 2022-08-18 10:48:12,336] A new study created in memory with name: CatBoostRegressor
# /Users/maksimkeller/opt/anaconda3/lib/python3.9/site-packages/optuna/progress_bar.py:47: ExperimentalWarning: Progress bar is experimental (supported from v1.2.0). The interface can change in the future.
#   self._init_valid()
#   0%|          | 0
2s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 6.248260966
# bestIteration = 427
#
# Shrink model to first 428 iterations.
# [I 2022-08-18 10:53:16,164] Trial 9 finished with value: 6.434454501133951 and parameters: {'learning_rate': 0.02892945666385754, 'max_depth': 11, 'l2_leaf_reg': 3.5, 'min_child_samples': 32}. Best is trial 3 with value: 5.9825748945832276.

# %%
print(f"\t Значение метрики (MAE): {study_cat.best_value:.1f}")
# Out:
# 	 Значение метрики (MAE): 6.0

# %% [markdown]
# ### Validation on the test dataset

# %% [markdown]
# At this stage, we will check the quality metric on a previously unused set (test set) to ensure the quality of the model.

# %%
pred = rnd_search_cat.predict(features_test)
mae = mean_absolute_error(target_test, pred)
print('MAE: {:.1f}'.format(mae))
# Out:
# MAE: 5.4

# %% [markdown]
# ### Adequacy check

# %% [markdown]
# At this step, we will make sure that the constructed model is adequate by comparing it with the model that predicts the average temperature value.

# %%
dummy_regr = DummyRegressor(strategy="mean")
dummy_regr.fit(features_train, target_train)

predictions_dummy = dummy_regr.predict(features_test)

result_dummy = mean_absolute_error(target_test, predictions_dummy)

print('MAE модели:', round(result_dummy, 2))
# Out:
# MAE модели: 7.81

# %% [markdown]
# ### Conclusion
#
# In this section, 5 models were built to predict the resulting boiler temperature. The CatBoost gradient boosting model showed the best result. Checking the results on the test sample showed the stability of the result on an independent sample, the test for adequacy was passed, the model is able to sufficiently effectively predict the resulting temperature of the alloy.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# This study was created for the metallurgical plant LLC "So temper steel". The purpose of the study: Optimization of production processes through the construction of a model that predicts the temperature of the steel. The target metric of this study is MAE, i.e. mean absolute error. At the beginning of the study, a plan was drawn up, consisting of three pillars: Conducting exploratory data analysis, Pre-processing and machine learning, and a final report.
#
# Each of the stages was completed in full. A study was carried out in order to get acquainted with the technological process, an analysis of data from the customer was carried out. Seven tables were studied:
# - `data_arc.csv` — electrode data;
# - `data_bulk.csv` - data on the supply of bulk materials (volume);
# - `data_bulk_time.csv` - data on the supply of bulk materials (time);
# - `data_gas.csv` — data on alloy gas purge;
# - `data_temp.csv` - temperature measurement results;
# - `data_wire.csv` - data on wire materials (volume);
# - `data_wire_time.csv` - data on wire materials (time).
#
# It was determined that the data contained errors (Negative reactive power in the data_arc table and a temperature below the melting temperature in the ata_temp table). The distribution patterns of the used wire materials (table data_wire) and loose powders (table data_bulk) were studied. It was found that not all distributions correspond to normal ones. It is important to note that there are gaps in the data and some of the dimensions were missing for some keys, so when creating the pivot table, we used the inner join method.
#
# At the next stage, the data was preprocessed and combined into a single table. At this stage, the key was excluded from the data_arc table, where the reactive power has a negative value, and the active power is greater than 3.5. When working with the data_arc table, new features were introduced - the total arc heating time for each key, the number of heatings for each key, and the ratio of active to reactive power. Next, the data_bulk and data_bulk_time tables were worked out. New features have been added - the amount of added bulk material and the time between adding the first and last bulk material. The data_gas table was taken unchanged. By analogy with the data_bulk and data_bulk_time tables, transformations were made in the data_wire and data_wire_time tables. The Wire 5 attribute was removed from the data_wire table, because in the entire set under study, it occurs once and cannot affect the result of the prediction. Based on similar considerations, the feature Bulk 8 was removed from the study. Further, keys were removed from the data_temp table, where the ladle temperature was lower than the melting temperature this is contrary to the studied technological process. A sign was also added - the primary temperature.
#
# Then, after combining all the features into a single table, a heatmap was generated showing the degree of correlation between the features. It can be seen that between some features there is a high (absolute value above 0.9) degree of correlation. So the correlation coefficient between active and reactive power is 0.92, and between Bulk 12 and Bulk 7 the correlation coefficient is equal to one. As a result, it was decided to remove from consideration the following features with a high degree of correlation with other features: 'Reactive power', 'Bulk 7', 'Bulk 9', 'Wire 2', 'Wire 8', 'Wire 9'. The final step of this section was to split the set into training and test sets.
#
# Next, the models will be trained on a set of 28 features: Power ratio, Total heating time, Number of heatings, Bulk 1, Bulk 2, Bulk 3, Bulk 4, Bulk 5, Bulk 6, Bulk 10, Bulk 11, Bulk 12, Bulk 13, Bulk 14, Bulk 15, Bulk count, Bulk additive time, Gas 1, Wire 1, Wire 3, Wire 4, Wire 6, Wire 7, Wire count, Wire time, First temperature, Number of temperature readings.
#
#
# The next important block of research is the construction of predictive models and the choice of the best one. For this study, linear regression, decision tree, random forest, lgbmregressor and catboostregressor models were prepared and tested. Each of the models was trained using cross-validation and neg_mean_absolute_error scoring, the absolute value of which gives the target metric of this MAE study. All models showed a sufficiently good result and, with proper selection of hyperparameters, are able to obtain the required metric, however, the CatBoostRegressor model was chosen for further work. For this model, a diagram was drawn showing the importance of the features. From the data obtained, it can be established that the Bulk 2, Bulk 13, Wire 7, Wire 4 features have a low degree of significance in constructing a prediction and, therefore, can be removed from the study. Next, this model was run using the optuna algorithm to find the optimal hyperparameters. As a result of the work, the MAE metric on the training sample was 5.98. The parameters turned out to be optimal:
# 'learning_rate': 0.02892945666385754, 'max_depth': 11, 'l2_leaf_reg': 3.5, 'min_child_samples': 32 and random_state=80822.
# The learning_rate parameter is responsible for the learning rate and is one of the main ones in models that use gradient descent.
# The max_depth parameter is responsible for the maximum depth of the trees underlying the gradient boosting models.
# The l2_leaf_reg parameter is the coefficient of the L2 regularization term.
# The min_child_samples parameter is responsible for the minimum amount of data on the sheet. The random_state parameter is responsible for the reproducibility of the result. It was the search for the best combinations among these parameters that showed the best result of the metric.
# To control the independence of the result from the existing sample, the model was tested on a test set and showed MAE 5.4, which may indicate the reproducibility of the result.
#
# Separately, a check was carried out, the purpose of which is to check the adequacy of the spent resource for the resulting result. The comparison was carried out with a model predicting the average temperature in the training sample. The MAE of such a predictive model turned out to be higher than that of the trained model.
#
# The most difficult in this study was the process of selecting hyperparameters that would allow us to obtain a quality metric lower than with the default parameters. The complexity was caused not only by the choice of intervals in which the search for optimal values is performed, but also by a combination of features that can give the desired result, so that the model training time does not exceed several hours. After several iterations of the search, the desired combination of parameters and intervals was found and the model showed the best result, while the search time for optimal parameters remained acceptable.
#
#
# The result of this study was a CatBoostRegressor model with parameters 'learning_rate': 0.02892945666385754, 'max_depth': 11, 'l2_leaf_reg': 3.5, 'min_child_samples': 32 and fixed parameter random_state equal to 80822 trained on 28 signs, it is capable of predicting the temperature of the ladle heating with an error of MAE 5.9, which corresponds to the purpose of the study.
